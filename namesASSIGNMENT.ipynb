# %%
with open("task.txt","r") as f:
    data = f.read()

# %%
print(data)
# Out:
# GEORGE MCINTOSH
# JOHN	ARCHER
# MARKEETA	KLINEFELTER
# JUDITH	BEAL
# ROBERTO	REYES
# JOANNE	KELDERMAN
# FLEETA	ARTHUR
# SHARON	JACOBS
# LELA	FARMER
# CATHERINE	EVANS
# COURTNEY	CAIN
# MARCIA	SEIFRIG
# SARAH	MORRIS
# MARY	AMOS
# JERRY	COURTS
# REVEL	MASSIE
# GLORIA	WISEMAN
# EDNA	MCFALL
# DOREEN	HARMON
# JAMES	HOWARD
# DAVID	BOOE
# SUSAN	PROUGH
# STEVE	MILLER
# VICTORIANO	RAMIREZ
# ANDREW	COSENTINO
# BRENDA	SALLEE
# SYLVIA	SCROGGINS
# JO	DOYLE
# VICKY	MATTHIAS
# CRAIG	SAPONKA
# ROBERT	JERINA
# MELISSA	STUTSMAN
# STEVEN	KROUSE
# MIKE	FRAZEE
# JULIAN	CHASTAIN
# MARVIN	VAN
# VICKI	BELL
# JANE	LENTINE
# APRIL	SCHWARTZ
# CHERYL	WASHINGTON
# JOHNNIE	STANSON
# LINDA	DONNELLY
# CLARA	HOLMES
# CAROLYN	KETCHEM
# POLLY	SHULL
# THERESA	HANDSHOE
# CONSTANCE	KRESS
# NORA	CASSIDY
# ANN	HARGETT
# WILLIAM	THOMASON
# LORI	HELTON
# ALBERTA	BEAVER
# K	ROGERS
# DELORES	RAGENS
# JEANETTE	KACZMAREK
# BARBARA	NAVE
# JON	CROWE
# DAPHNE	ROSS
# LYNN	HAYES
# CATHY	ALLEN
# ED	NEWTON
# KIM	CASE
# PATRICIA	BUNNER
# ...

# %%
listt = data.split()

# %%
print(listt)
# Out:
# ['GEORGE', 'MCINTOSH', 'JOHN', 'ARCHER', 'MARKEETA', 'KLINEFELTER', 'JUDITH', 'BEAL', 'ROBERTO', 'REYES', 'JOANNE', 'KELDERMAN', 'FLEETA', 'ARTHUR', 'SHARON', 'JACOBS', 'LELA', 'FARMER', 'CATHERINE', 'EVANS', 'COURTNEY', 'CAIN', 'MARCIA', 'SEIFRIG', 'SARAH', 'MORRIS', 'MARY', 'AMOS', 'JERRY', 'COURTS', 'REVEL', 'MASSIE', 'GLORIA', 'WISEMAN', 'EDNA', 'MCFALL', 'DOREEN', 'HARMON', 'JAMES', 'HOWARD', 'DAVID', 'BOOE', 'SUSAN', 'PROUGH', 'STEVE', 'MILLER', 'VICTORIANO', 'RAMIREZ', 'ANDREW', 'COSENTINO', 'BRENDA', 'SALLEE', 'SYLVIA', 'SCROGGINS', 'JO', 'DOYLE', 'VICKY', 'MATTHIAS', 'CRAIG', 'SAPONKA', 'ROBERT', 'JERINA', 'MELISSA', 'STUTSMAN', 'STEVEN', 'KROUSE', 'MIKE', 'FRAZEE', 'JULIAN', 'CHASTAIN', 'MARVIN', 'VAN', 'VICKI', 'BELL', 'JANE', 'LENTINE', 'APRIL', 'SCHWARTZ', 'CHERYL', 'WASHINGTON', 'JOHNNIE', 'STANSON', 'LINDA', 'DONNELLY', 'CLARA', 'HOLMES', 'CAROLYN', 'KETCHEM', 'POLLY', 'SHULL', 'THERESA', 'HANDSHOE', 'CONSTANCE', 'KRESS', 'NORA', 'CASSIDY', 'ANN', 'HARGETT', 'WILLIAM',
# ...

# %%
for count,i in enumerate(listt):
    print(count)
    print(i)
# Out:
# 0
# GEORGE
# 1
# MCINTOSH
# 2
# JOHN
# 3
# ARCHER
# 4
# MARKEETA
# 5
# KLINEFELTER
# 6
# JUDITH
# 7
# BEAL
# 8
# ROBERTO
# 9
# REYES
# 10
# JOANNE
# 11
# KELDERMAN
# 12
# FLEETA
# 13
# ARTHUR
# 14
# SHARON
# 15
# JACOBS
# 16
# LELA
# 17
# FARMER
# 18
# CATHERINE
# 19
# EVANS
# 20
# COURTNEY
# 21
# CAIN
# 22
# MARCIA
# 23
# SEIFRIG
# 24
# SARAH
# 25
# MORRIS
# 26
# MARY
# 27
# AMOS
# 28
# JERRY
# 29
# COURTS
# 30
# REVEL
# 31
# MASSIE
# 32
# GLORIA
# 33
# WISEMAN
# 34
# EDNA
# 35
# MCFALL
# 36
# DOREEN
# 37
# HARMON
# 38
# JAMES
# 39
# HOWARD
# 40
# DAVID
# 41
# BOOE
# 42
# SUSAN
# 43
# PROUGH
# 44
# STEVE
# 45
# MILLER
# 46
# VICTORIANO
# 47
# RAMIREZ
# 48
# ANDREW
# 49
# COSENTINO
# 50
# BRENDA
# 51
# SALLEE
# 52
# SYLVIA
# 53
# SCROGGINS
# 54
# JO
# 55
# DOYLE
# 56
# VICKY
# 57
# MATTHIAS
# 58
# CRAIG
# 59
# SAPONKA
# 60
# ROBERT
# 61
# JERINA
# 62
# MELISSA
# 63
# STUTSMAN
# 64
# STEVEN
# 65
# KROUSE
# 66
# MIKE
# 67
# FRAZEE
# 68
# JULIAN
# 69
# CHASTAIN
# 70
# MARVIN
# 71
# VAN
# ...

# %%
first_names = []

# %%
for j in range(0,197,2):
    print(listt[j])
    first_names.append(listt[j])
# Out:
# GEORGE
# JOHN
# MARKEETA
# JUDITH
# ROBERTO
# JOANNE
# FLEETA
# SHARON
# LELA
# CATHERINE
# COURTNEY
# MARCIA
# SARAH
# MARY
# JERRY
# REVEL
# GLORIA
# EDNA
# DOREEN
# JAMES
# DAVID
# SUSAN
# STEVE
# VICTORIANO
# ANDREW
# BRENDA
# SYLVIA
# JO
# VICKY
# CRAIG
# ROBERT
# MELISSA
# STEVEN
# MIKE
# JULIAN
# MARVIN
# VICKI
# JANE
# APRIL
# CHERYL
# JOHNNIE
# LINDA
# CLARA
# CAROLYN
# POLLY
# THERESA
# CONSTANCE
# NORA
# ANN
# WILLIAM
# LORI
# ALBERTA
# K
# DELORES
# JEANETTE
# BARBARA
# JON
# DAPHNE
# LYNN
# CATHY
# ED
# KIM
# PATRICIA
# CHRISTIE
# JESSE
# DANIEL
# DOROTHY
# WILLIE
# SONNA
# RENOVA
# ROSETTA
# TERESA
# BONNIE
# CHARLES
# BETTY
# WANDA
# RICHARD
# JOSEPH
# STELLA
# SANDRA
# MARTHA
# DENNIS
# N
# MICHAEL
# JANNIE
# GREGORY
# DIANE
# KATHY
# PAUL
# LARRY
# THOMAS
# MARLENE
# LUANNE
# CURTIS
# DEANNA
# DONNA
# KENNETH
# ROGER
# HENRY

# %%
last_names = []

# %%
for i in range(1,197,2):
    print(listt[i])
    last_names.append(listt[i])
# Out:
# MCINTOSH
# ARCHER
# KLINEFELTER
# BEAL
# REYES
# KELDERMAN
# ARTHUR
# JACOBS
# FARMER
# EVANS
# CAIN
# SEIFRIG
# MORRIS
# AMOS
# COURTS
# MASSIE
# WISEMAN
# MCFALL
# HARMON
# HOWARD
# BOOE
# PROUGH
# MILLER
# RAMIREZ
# COSENTINO
# SALLEE
# SCROGGINS
# DOYLE
# MATTHIAS
# SAPONKA
# JERINA
# STUTSMAN
# KROUSE
# FRAZEE
# CHASTAIN
# VAN
# BELL
# LENTINE
# SCHWARTZ
# WASHINGTON
# STANSON
# DONNELLY
# HOLMES
# KETCHEM
# SHULL
# HANDSHOE
# KRESS
# CASSIDY
# HARGETT
# THOMASON
# HELTON
# BEAVER
# ROGERS
# RAGENS
# KACZMAREK
# NAVE
# CROWE
# ROSS
# HAYES
# ALLEN
# NEWTON
# CASE
# BUNNER
# MCCLENDON
# ALEXANDER
# SEXTON
# BLACKWELL
# BATTEN
# BALL
# SCOTT
# KENAR
# READY
# GREEN
# WILSON
# NELSON
# WILLIAMS
# PLOUGH
# CLOWER
# CAGLE
# HOFFMAN
# PREBLE
# PAPENLEUR
# THOMPSON
# KUHN
# BARNES
# CRONKHITE
# HARRIS
# SMITH
# CANTWELL
# HUFF
# RAGOZZINO
# ANTHONY
# MADISON
# DURANCZYK
# LEGLER
# BOYD
# FEHR
# PERKINS

# %%
first_names
# Out:
# ['GEORGE',
#  'JOHN',
#  'MARKEETA',
#  'JUDITH',
#  'ROBERTO',
#  'JOANNE',
#  'FLEETA',
#  'SHARON',
#  'LELA',
#  'CATHERINE',
#  'COURTNEY',
#  'MARCIA',
#  'SARAH',
#  'MARY',
#  'JERRY',
#  'REVEL',
#  'GLORIA',
#  'EDNA',
#  'DOREEN',
#  'JAMES',
#  'DAVID',
#  'SUSAN',
#  'STEVE',
#  'VICTORIANO',
#  'ANDREW',
#  'BRENDA',
#  'SYLVIA',
#  'JO',
#  'VICKY',
#  'CRAIG',
#  'ROBERT',
#  'MELISSA',
#  'STEVEN',
#  'MIKE',
#  'JULIAN',
#  'MARVIN',
#  'VICKI',
#  'JANE',
#  'APRIL',
#  'CHERYL',
#  'JOHNNIE',
#  'LINDA',
#  'CLARA',
#  'CAROLYN',
#  'POLLY',
#  'THERESA',
#  'CONSTANCE',
#  'NORA',
#  'ANN',
#  'WILLIAM',
#  'LORI',
#  'ALBERTA',
#  'K',
#  'DELORES',
#  'JEANETTE',
#  'BARBARA',
#  'JON',
#  'DAPHNE',
#  'LYNN',
#  'CATHY',
#  'ED',
#  'KIM',
#  'PATRICIA',
#  'CHRISTIE',
#  'JESSE',
#  'DANIEL',
#  'DOROTHY',
#  'WILLIE',
#  'SONNA',
#  'RENOVA',
#  'ROSETTA',
#  'TERESA',
#  'BONNIE',
#  'CHARLES',
#  'BETTY',
#  'WANDA',
#  'RICHARD',
#  'JOSEPH',
# ...

# %%
last_names
# Out:
# ['MCINTOSH',
#  'ARCHER',
#  'KLINEFELTER',
#  'BEAL',
#  'REYES',
#  'KELDERMAN',
#  'ARTHUR',
#  'JACOBS',
#  'FARMER',
#  'EVANS',
#  'CAIN',
#  'SEIFRIG',
#  'MORRIS',
#  'AMOS',
#  'COURTS',
#  'MASSIE',
#  'WISEMAN',
#  'MCFALL',
#  'HARMON',
#  'HOWARD',
#  'BOOE',
#  'PROUGH',
#  'MILLER',
#  'RAMIREZ',
#  'COSENTINO',
#  'SALLEE',
#  'SCROGGINS',
#  'DOYLE',
#  'MATTHIAS',
#  'SAPONKA',
#  'JERINA',
#  'STUTSMAN',
#  'KROUSE',
#  'FRAZEE',
#  'CHASTAIN',
#  'VAN',
#  'BELL',
#  'LENTINE',
#  'SCHWARTZ',
#  'WASHINGTON',
#  'STANSON',
#  'DONNELLY',
#  'HOLMES',
#  'KETCHEM',
#  'SHULL',
#  'HANDSHOE',
#  'KRESS',
#  'CASSIDY',
#  'HARGETT',
#  'THOMASON',
#  'HELTON',
#  'BEAVER',
#  'ROGERS',
#  'RAGENS',
#  'KACZMAREK',
#  'NAVE',
#  'CROWE',
#  'ROSS',
#  'HAYES',
#  'ALLEN',
#  'NEWTON',
#  'CASE',
#  'BUNNER',
#  'MCCLENDON',
#  'ALEXANDER',
#  'SEXTON',
#  'BLACKWELL',
#  'BATTEN',
#  'BALL',
#  'SCOTT',
#  'KENAR',
#  'READY',
#  'GREEN',
#  'WILSON',
#  'NELSON',
# ...

# %%
for i in first_names:
    for j in last_names:
        res = i + " " + j
        with open("all_names.txt", "a") as f:
            f.write("\n" + res)
